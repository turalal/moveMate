# %%
# !pip install --upgrade pip
# 1. First uninstall all conflicting packages
# !pip uninstall -y numpy tensorflow fastai tf-keras tensorflow-text pydicom gdcm pylibjpeg pylibjpeg-libjpeg

# 2. Install base packages with specific versions
# !pip install --no-deps numpy==1.23.5
# !pip install tensorflow==2.16.1
# !pip install pydicom

# 3. Install DICOM handling packages
# !pip install gdcm
# !pip install pylibjpeg
# !pip install pylibjpeg-libjpeg

# 4. Install fastai with no dependencies (to avoid conflicts)
# !pip install --no-deps fastai==2.7.18

# 5. Install ipywidgets for progress bars
# !pip install ipywidgets
# Out:
# ...
# Found existing installation: numpy 2.1.2
# Uninstalling numpy-2.1.2:
#   Successfully uninstalled numpy-2.1.2
# WARNING: Skipping tensorflow as it is not installed.
# WARNING: Skipping fastai as it is not installed.
# WARNING: Skipping tf-keras as it is not installed.
# WARNING: Skipping tensorflow-text as it is not installed.
# WARNING: Skipping pydicom as it is not installed.
# WARNING: Skipping gdcm as it is not installed.
# WARNING: Skipping pylibjpeg as it is not installed.
# WARNING: Skipping pylibjpeg-libjpeg as it is not installed.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 1.4 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/Users/ismatsamadov/breast_cancer_detection/.venv/lib/python3.13/site-packages/pip/_internal/cli/base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
# ...
